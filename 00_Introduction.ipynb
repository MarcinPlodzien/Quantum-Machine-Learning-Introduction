# %% [markdown]
# # Simulating Parametrized Quantum Circuits
# ## VQE, and QAOA implementation from scratch with pure PyTorch
#
# ### Marcin Płodzień, ICFO
# ### VI Pyrenees Winter School
# ### Quantum Information Meeting for Barcelona's Community
# ### 14-17.02.2023

# %% [markdown]
# ![VQE_image.png](attachment:VQE_image.png)

# %% [markdown]
# ### The core of "quantum" libraries consits of:
# ### 1. Exact Diagonalization methods for spin-1/2 chains
# ### 2. Automatic Differentiation techniuqes for parameters optimization

# %% [markdown]
# ## In this tutorial we'll implement basics tools for simulating (parametrized) quantum circuits  from scratch with Variational Quantum Eigensolver (VQE), and Quantum Approximate Optimization Algorithm (QAOA) from scratch.
#
# ## Outline:
# ### 1. Automatic Differentiation
# ### 2. Exact-Diagonalization methods for qubits (spin-1/2 chain) : quantum gates implementation from scratch
# ### 3. Examples: Variational Quantum Eigensolver (VQE) implementation from scratch
# ### 4. Examples: Quantum Approximate Optimization Algorithm (QAOA) implementation from scratch

# %% [markdown]
# ## For more details about Quantum Machine Learning see
#
# ## [Modern application of machine learning in quantum sciences](https://arxiv.org/abs/2204.04198)
#
# ![book.png](attachment:book.png)
